# %% [markdown]
# loading required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
from scipy.stats import skew,normaltest
from sklearn.decomposition import PCA

# %% [markdown]
# loading dataset

# %%
df = pd.read_csv("Food_Time_Data_Set.csv")
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 0                    75.912471        Snack      motorcycle         17.11
# 1                    77.813237        Snack         scooter         19.50
# 2                    77.688400       Drinks      motorcycle         20.45
# 3                    77.026494       Buffet      motorcycle         23.86
# 4                    80.289982        Snack         scooter         26.55
#
#    humidity  precipitation weather_description  Unnamed: 14 Traffic_Level  \
# 0      77.0            0.0                haze          NaN           Low
# 1      93.0            0.0                mist          NaN     Very High
# 2      91.0            0.0                mist          NaN           Low
# 3      78.0            0.0                mist          NaN      Moderate
# 4      87.0            0.0                mist          NaN          High
#
#    Distance (km)       TARGET
# 0            NaN  21.66666667
# 1          37.17  85.26666667
# 2           3.34  28.58333333
# 3          10.05  35.18333333
# 4           9.89        43.45

# %% [markdown]
# general info about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
#  12  precipitation                9995 non-null   float64
#  13  weather_description          9995 non-null   object
#  14  Unnamed: 14                  0 non-null      float64
#  15  Traffic_Level                9085 non-null   object
#  16  Distance (km)                9080 non-null   float64
#  17  TARGET                       9459 non-null   object
# dtypes: float64(11), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# handling missing values

# %%
df.isna().sum()
# Out:
# ID                                 1
# Delivery_person_ID                 1
# Delivery_person_Age                1
# Delivery_person_Ratings            1
# Restaurant_latitude                1
# Restaurant_longitude               1
# Delivery_location_latitude         1
# Delivery_location_longitude        1
# Type_of_order                      1
# Type_of_vehicle                    1
# temperature                        6
# humidity                           6
# precipitation                      6
# weather_description                6
# Unnamed: 14                    10001
# Traffic_Level                    916
# Distance (km)                    921
# TARGET                           542
# dtype: int64

# %%
#finding index of the first 8 colums because they only have one missing value
for i in df.iloc[:, :8].columns:
    df1 = df[df[i].isna()].index
    print(df1)
# Out:
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')
# Index([10000], dtype='int64')

# %% [markdown]
# since the index of all those value is 100000. it shows the row 100000 has the most mising values so ill remove that rown. which will cause no trouble in data.

# %%
df.drop(10000, inplace=True)
df.drop_duplicates(inplace=True)
df.isna().sum()
# Out:
# ID                                 0
# Delivery_person_ID                 0
# Delivery_person_Age                0
# Delivery_person_Ratings            0
# Restaurant_latitude                0
# Restaurant_longitude               0
# Delivery_location_latitude         0
# Delivery_location_longitude        0
# Type_of_order                      0
# Type_of_vehicle                    0
# temperature                        5
# humidity                           5
# precipitation                      5
# weather_description                5
# Unnamed: 14                    10000
# Traffic_Level                    915
# Distance (km)                    920
# TARGET                           541
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 12396

# %%
for i in df.columns: #finding unique values in each column
    if len(df[i].unique()) <= 20: #if unique values are less then 20. i will consider it as catagoriacal data and print the unique values
        print(f'-----{i}---------')
        df1 = df[i].unique()  
        for j in range(len(df1)):
            k = (df[i] == df1[j]).sum()
            print(f'{df1[j]} = {k}')
    else: #if unique values are more than 20 then continuous data but still show the number of unique values
        print(f'####{i} has {len(df[i].unique())} unique values.')
# Out:
# ####ID has 9995 unique values.
# ####Delivery_person_ID has 1285 unique values.
# ####Delivery_person_Age has 22 unique values.
# ####Delivery_person_Ratings has 28 unique values.
# ####Restaurant_latitude has 485 unique values.
# ####Restaurant_longitude has 427 unique values.
# ####Delivery_location_latitude has 3445 unique values.
# ####Delivery_location_longitude has 3445 unique values.
# -----Type_of_order---------
# Snack  = 2551
# Drinks  = 2507
# Buffet  = 2412
# Meal  = 2530
# -----Type_of_vehicle---------
# motorcycle  = 5862
# scooter  = 3304
# electric_scooter  = 814
# bicycle  = 20
# ####temperature has 1070 unique values.
# ####humidity has 65 unique values.
# ####precipitation has 36 unique values.
# -----weather_description---------
# haze = 2406
# mist = 1751
# broken clouds = 721
# clear sky = 3260
# scattered clouds = 422
# overcast clouds = 308
# light rain = 536
# smoke = 501
# fog = 49
# few clouds = 40
# nan = 0
# moderate rain = 1
# -----Unnamed: 14---------
# nan = 0
# -----Traffic_Level---------
# Low = 1726
# Very High = 1772
# Moderate = 2219
# High = 2736
# Very Low = 632
# nan = 0
# ####Distance (km) has 2344 unique values.
# ####TARGET has 3390 unique values.

# %% [markdown]
# column unamed seems like an empty column

# %%
df.drop(columns=['Unnamed: 14'], inplace=True, errors='ignore')

# %%
print(df.columns)
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'temperature', 'humidity', 'precipitation', 'weather_description',
#        'Traffic_Level', 'Distance (km)', 'TARGET'],
#       dtype='object')

# %%
missing_rows = df[df['temperature'].isna()].index
print(missing_rows)
missing_rows=[]
missing_rows = df[df['humidity'].isna()].index
print(missing_rows)
missing_rows=[]
missing_rows = df[df['precipitation'].isna()].index
print(missing_rows)
missing_rows=[]
missing_rows = df[df['weather_description'].isna()].index
print(missing_rows)
# Out:
# Index([5000, 6000, 7000, 8000, 9000], dtype='int64')
# Index([5000, 6000, 7000, 8000, 9000], dtype='int64')
# Index([5000, 6000, 7000, 8000, 9000], dtype='int64')
# Index([5000, 6000, 7000, 8000, 9000], dtype='int64')

# %%
df.drop([5000,6000,7000,8000,9000], inplace=True)

# %%
df.isna().sum()
# Out:
# ID                               0
# Delivery_person_ID               0
# Delivery_person_Age              0
# Delivery_person_Ratings          0
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Type_of_order                    0
# Type_of_vehicle                  0
# temperature                      0
# humidity                         0
# precipitation                    0
# weather_description              0
# Traffic_Level                  915
# Distance (km)                  920
# TARGET                         536
# dtype: int64

# %%
columns_to_check = ['Traffic_Level', 'Distance (km)']

# Find rows where only one column is missing (not both)
rows_with_single_missing = []

for idx, row in df[columns_to_check].iterrows():
    missing_count = row.isna().sum()
    if missing_count == 1:  # Only one missing (not both)
        rows_with_single_missing.append(idx)

print("Rows where only one value is missing (not both):", rows_with_single_missing)
# Out:
# Rows where only one value is missing (not both): [0, 2028, 2969, 9753, 9755]

# %%
column_to_check = "Traffic_Level"  # You can change this to any column name

# Split into two datasets
df_no_missing = df[df[column_to_check].notna()]  # Rows where the column is NOT missing
df_missing = df[df[column_to_check].isna()]      # Rows where the column IS missing

df_missing
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33    2876   RANCHIRES02DEL01                 32.0                      3.5
# 52    C1FF     AURGRES20DEL03                 25.0                      5.0
# 57    8E6C      VADRES02DEL02                 39.0                      4.2
# 59    395B      VADRES04DEL03                 36.0                      4.7
# 67    98AA      VADRES16DEL02                 23.0                      4.8
# ...    ...                ...                  ...                      ...
# 9919  D4DC      ALHRES04DEL02                 24.0                      4.7
# 9921  C032      KOLRES08DEL01                 28.0                      4.7
# 9960  D1F1     AURGRES20DEL01                 21.0                      4.9
# 9977  C5A8      BHPRES14DEL02                 24.0                      4.8
# 9988  C7C4      KNPRES08DEL01                 22.0                      4.3
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 33                0.00000              0.000000                     0.11000
# 52                0.00000              0.000000                     0.03000
# 57                0.00000              0.000000                     0.08000
# 59                0.00000              0.000000                     0.06000
# 67                0.00000              0.000000                     0.02000
# ...                   ...                   ...                         ...
# 9919              0.00000              0.000000                     0.13000
# 9921            -22.53796             88.349843                    22.60796
# 9960              0.00000              0.000000                     0.11000
# 9977              0.00000              0.000000                     0.08000
# 9988              0.00000              0.000000                     0.04000
#
#       Delivery_location_longitude Type_of_order    Type_of_vehicle  \
# 33                       0.110000        Snack            scooter
# 52                       0.030000        Snack         motorcycle
# 57                       0.080000        Snack            scooter
# 59                       0.060000        Snack         motorcycle
# 67                       0.020000         Meal            scooter
# ...                           ...           ...                ...
# 9919                     0.130000       Buffet            scooter
# 9921                    88.419843         Meal            scooter
# 9960                     0.110000        Snack   electric_scooter
# 9977                     0.080000        Snack            scooter
# 9988                     0.040000       Drinks         motorcycle
#
#       temperature  humidity  precipitation weather_description Traffic_Level  \
# 33          26.27      84.0           0.00     overcast clouds           NaN
# 52          26.28      85.0           0.10          light rain           NaN
# 57          26.25      85.0           0.00     overcast clouds           NaN
# 59          26.28      84.0           0.00       broken clouds           NaN
# 67          26.29      85.0           0.11          light rain           NaN
# ...           ...       ...            ...                 ...           ...
# 9919        26.44      82.0           0.23          light rain           NaN
# 9921        28.00      65.0           0.00                haze           NaN
# 9960        26.41      82.0           0.25          light rain           NaN
# 9977        26.37      82.0           0.27          light rain           NaN
# 9988        26.34      82.0           0.30          light rain           NaN
#
#       Distance (km)   TARGET
# 33              NaN  #VALUE!
# 52              NaN      NaN
# 57              NaN  #VALUE!
# 59              NaN  #VALUE!
# 67              NaN      NaN
# ...             ...      ...
# 9919            NaN      NaN
# 9921            NaN  #VALUE!
# 9960            NaN      NaN
# 9977            NaN      NaN
# 9988            NaN      NaN
#
# [915 rows x 17 columns]

# %%
df_no_missing
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0     4607     INDORES13DEL02                 37.0                      4.9
# 1     B379     BANGRES18DEL02                 34.0                      4.5
# 2     5D6D     BANGRES19DEL01                 23.0                      4.4
# 3     7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4     70A2     CHENRES12DEL01                 32.0                      4.6
# ...    ...                ...                  ...                      ...
# 9995  4347      MUMRES07DEL01                 25.0                      4.0
# 9996  11B4      VADRES13DEL03                 32.0                      4.2
# 9997  8336      HYDRES20DEL01                 36.0                      4.7
# 9998  338B      JAPRES18DEL03                 37.0                      4.6
# 9999  3FB2      MUMRES11DEL03                 29.0                      4.7
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0               22.745049             75.892471                   22.765049
# 1               12.913041             77.683237                   13.043041
# 2               12.914264             77.678400                   12.924264
# 3               11.003669             76.976494                   11.053669
# 4               12.972793             80.249982                   13.012793
# ...                   ...                   ...                         ...
# 9995            19.091458             72.827808                   19.101458
# 9996            22.310237             73.158921                   22.400237
# 9997            17.483216             78.552111                   17.493216
# 9998            26.913987             75.752891                   27.053987
# 9999            18.994237             72.825553                   19.084237
#
#       Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 0                       75.912471        Snack      motorcycle         17.11
# 1                       77.813237        Snack         scooter         19.50
# 2                       77.688400       Drinks      motorcycle         20.45
# 3                       77.026494       Buffet      motorcycle         23.86
# 4                       80.289982        Snack         scooter         26.55
# ...                           ...           ...             ...          ...
# 9995                    72.837808         Meal      motorcycle         28.03
# 9996                    73.248921         Meal      motorcycle         23.96
# 9997                    78.562111         Meal      motorcycle         22.94
# 9998                    75.892891       Buffet         scooter         23.72
# 9999                    72.915553         Meal         scooter         28.01
#
#       humidity  precipitation weather_description Traffic_Level  \
# 0         77.0            0.0                haze           Low
# 1         93.0            0.0                mist     Very High
# 2         91.0            0.0                mist           Low
# 3         78.0            0.0                mist      Moderate
# 4         87.0            0.0                mist          High
# ...        ...            ...                 ...           ...
# 9995      57.0            0.0               smoke           Low
# 9996      64.0            0.0                haze          High
# 9997      60.0            0.0                haze           Low
# 9998      31.0            0.0           clear sky     Very High
# 9999      57.0            0.0               smoke          High
#
#       Distance (km)       TARGET
# 0               NaN  21.66666667
# 1             37.17  85.26666667
# 2              3.34  28.58333333
# 3             10.05  35.18333333
# 4              9.89        43.45
# ...             ...          ...
# 9995           3.78         18.2
# 9996          18.92  32.61666667
# 9997           2.64  12.01666667
# 9998          28.80  51.06666667
# 9999          17.63         43.8
#
# [9080 rows x 17 columns]

# %% [markdown]
# after checking dataset with missing value and dataset with not missing value in distance column i can tell the data on distance column with missing value has wrongly entered data so there is no loss of important data if i remove the rows with missing data. even though the missing rows are about 920 values because the longitude and lattitude is 0 for those values that means the data is wrong so its better to remove those rows.

# %%
df = df.dropna(subset=['Traffic_Level'])

# %%
df.isna().sum()
# Out:
# ID                              0
# Delivery_person_ID              0
# Delivery_person_Age             0
# Delivery_person_Ratings         0
# Restaurant_latitude             0
# Restaurant_longitude            0
# Delivery_location_latitude      0
# Delivery_location_longitude     0
# Type_of_order                   0
# Type_of_vehicle                 0
# temperature                     0
# humidity                        0
# precipitation                   0
# weather_description             0
# Traffic_Level                   0
# Distance (km)                   5
# TARGET                         40
# dtype: int64

# %%
le_veh= LabelEncoder()
df['Type_of_vehicle_encoded'] = le_veh.fit_transform(df['Type_of_vehicle'])
label_veh = dict(zip(le_veh.classes_, le_veh.transform(le_veh.classes_)))
print(label_veh)
le_ord= LabelEncoder()
df['Type_of_order_encoded'] = le_ord.fit_transform(df['Type_of_order'])
label_ord = dict(zip(le_ord.classes_, le_ord.transform(le_ord.classes_)))
print(label_ord)
le_wea= LabelEncoder()
df['weather_description_encoded'] = le_wea.fit_transform(df['weather_description'])
label_wea = dict(zip(le_wea.classes_, le_wea.transform(le_wea.classes_)))
print(label_wea)
le_tra= LabelEncoder()
df['Traffic_Level_encoded'] = le_tra.fit_transform(df['Traffic_Level'])
label_tra = dict(zip(le_tra.classes_, le_tra.transform(le_tra.classes_)))
print(label_tra)
# Out:
# {'bicycle ': 0, 'electric_scooter ': 1, 'motorcycle ': 2, 'scooter ': 3}
# {'Buffet ': 0, 'Drinks ': 1, 'Meal ': 2, 'Snack ': 3}
# {'broken clouds': 0, 'clear sky': 1, 'few clouds': 2, 'fog': 3, 'haze': 4, 'light rain': 5, 'mist': 6, 'moderate rain': 7, 'overcast clouds': 8, 'scattered clouds': 9, 'smoke': 10}
# {'High': 0, 'Low': 1, 'Moderate': 2, 'Very High': 3, 'Very Low': 4}

# %%
df1= df.drop(columns=['ID','Delivery_person_ID','Type_of_order','Type_of_vehicle','weather_description','Traffic_Level'],axis=1)

# %%
column_to_check = "Distance (km)"  # You can change this to any column name

# Split into two datasets
df_no_missing = df1[df1[column_to_check].notna()]  # Rows where the column is NOT missing
df_missing = df1[df1[column_to_check].isna()]      # Rows where the column IS missing

df_missing
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37.0                      4.9            22.745049
# 2028                 24.0                      4.9            23.374989
# 2969                 28.0                      4.4            11.022477
# 9753                 30.0                      3.6            11.003669
# 9755                 37.0                      4.6            19.109300
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 0                75.892471                   22.765049
# 2028             85.335486                   23.424989
# 2969             76.995667                   11.112477
# 9753             76.976494                   11.083669
# 9755             72.825451                   19.199300
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                       75.912471        17.11      77.0            0.0
# 2028                    85.385486        17.84      68.0            0.0
# 2969                    77.085667        25.12      73.0            0.0
# 9753                    77.056494        25.97      73.0            0.0
# 9755                    72.915451        26.96      57.0            0.0
#
#       Distance (km)       TARGET  Type_of_vehicle_encoded  \
# 0               NaN  21.66666667                        2
# 2028            NaN  43.18333333                        2
# 2969            NaN        45.85                        2
# 9753            NaN  32.73333333                        2
# 9755            NaN  70.33333333                        2
#
#       Type_of_order_encoded  weather_description_encoded  \
# 0                         3                            4
# 2028                      1                            1
# 2969                      1                            6
# 9753                      2                            4
# 9755                      2                           10
#
#       Traffic_Level_encoded
# 0                         1
# 2028                      0
# 2969                      0
# 9753                      0
# 9755                      3

# %% [markdown]
# only distance is missing other data is looking right. so ill predict the value for distance.

# %%
column_to_check = "TARGET"  # You can change this to any column name

# Split into two datasets
df_no_missing = df1[df1[column_to_check].notna()]  # Rows where the column is NOT missing
df_missing = df1[df1[column_to_check].isna()]      # Rows where the column IS missing

df_missing.head()
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 7131                 21.0                      4.9            13.066762
# 7343                 30.0                      4.5             9.979186
# 7359                 35.0                      4.6            13.005801
# 7375                 35.0                      4.6             9.970717
# 7397                 35.0                      4.5            13.081878
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 7131             80.251865                   13.196762
# 7343             76.317361                    9.999186
# 7359             80.250744                   13.115801
# 7375             76.285447                   10.000717
# 7397             80.248519                   13.191878
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 7131                    80.381865        28.35      76.0           0.17
# 7343                    76.337361        25.68      83.0           0.45
# 7359                    80.360744        28.40      82.0           0.15
# 7375                    76.315447        25.94      81.0           0.40
# 7397                    80.358519        28.34      86.0           0.14
#
#       Distance (km) TARGET  Type_of_vehicle_encoded  Type_of_order_encoded  \
# 7131          28.92    NaN                        1                      3
# 7343           4.47    NaN                        1                      1
# 7359          26.06    NaN                        2                      1
# 7375           8.95    NaN                        1                      2
# 7397          25.34    NaN                        3                      2
#
#       weather_description_encoded  Traffic_Level_encoded
# 7131                            5                      3
# 7343                            5                      1
# 7359                            5                      3
# 7375                            5                      2
# 7397                            5                      3

# %% [markdown]
# same goes for TARGET variable so ill use the same approach as i used for distance (km) to fill the missing data

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
def plot_correlations(df, target_column):
    """Plot correlations with the target column."""
    plt.figure(figsize=(10, 6))
    correlations = df.corr()[target_column].drop(target_column)
    sns.barplot(x=correlations.index, y=correlations.values)
    plt.title(f'Correlation with {target_column}')
    plt.xticks(rotation=90)
    plt.ylabel('Correlation Coefficient')
    plt.tight_layout()
    plt.show()

plot_correlations(df1, 'Distance (km)')

# %%
print("Columns in df1:", df1.columns.tolist())
df1.isna().sum()
# Out:
# Columns in df1: ['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'temperature', 'humidity', 'precipitation', 'Distance (km)', 'TARGET', 'Type_of_vehicle_encoded', 'Type_of_order_encoded', 'weather_description_encoded', 'Traffic_Level_encoded']
# Delivery_person_Age             0
# Delivery_person_Ratings         0
# Restaurant_latitude             0
# Restaurant_longitude            0
# Delivery_location_latitude      0
# Delivery_location_longitude     0
# temperature                     0
# humidity                        0
# precipitation                   0
# Distance (km)                   5
# TARGET                         40
# Type_of_vehicle_encoded         0
# Type_of_order_encoded           0
# weather_description_encoded     0
# Traffic_Level_encoded           0
# dtype: int64

# %%
df1_clean = df1.dropna()

# %%
df1_clean.isna().sum()
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# temperature                    0
# humidity                       0
# precipitation                  0
# Distance (km)                  0
# TARGET                         0
# Type_of_vehicle_encoded        0
# Type_of_order_encoded          0
# weather_description_encoded    0
# Traffic_Level_encoded          0
# dtype: int64

# %%
x=df1_clean[['Delivery_person_Ratings','humidity','weather_description_encoded','TARGET']]
y=df1_clean['Distance (km)'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=50)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50)

# %%
y_pred=rf.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print('The mean square error is :',mse)
print('The R2 score is :',r2)
# Out:
# The mean square error is : 14.485830535696996
# The R2 score is : 0.7995993400253147

# %%
column_to_check = "Distance (km)"  # You can change this to any column name

# Split into two datasets
df_no_missing = df1[df1[column_to_check].notna()]  # Rows where the column is NOT missing
df_missing = df1[df1[column_to_check].isna()]      # Rows where the column IS missing

df_missing
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37.0                      4.9            22.745049
# 2028                 24.0                      4.9            23.374989
# 2969                 28.0                      4.4            11.022477
# 9753                 30.0                      3.6            11.003669
# 9755                 37.0                      4.6            19.109300
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 0                75.892471                   22.765049
# 2028             85.335486                   23.424989
# 2969             76.995667                   11.112477
# 9753             76.976494                   11.083669
# 9755             72.825451                   19.199300
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                       75.912471        17.11      77.0            0.0
# 2028                    85.385486        17.84      68.0            0.0
# 2969                    77.085667        25.12      73.0            0.0
# 9753                    77.056494        25.97      73.0            0.0
# 9755                    72.915451        26.96      57.0            0.0
#
#       Distance (km)       TARGET  Type_of_vehicle_encoded  \
# 0               NaN  21.66666667                        2
# 2028            NaN  43.18333333                        2
# 2969            NaN        45.85                        2
# 9753            NaN  32.73333333                        2
# 9755            NaN  70.33333333                        2
#
#       Type_of_order_encoded  weather_description_encoded  \
# 0                         3                            4
# 2028                      1                            1
# 2969                      1                            6
# 9753                      2                            4
# 9755                      2                           10
#
#       Traffic_Level_encoded
# 0                         1
# 2028                      0
# 2969                      0
# 9753                      0
# 9755                      3

# %%
df_missing['Distance (km)']=rf.predict(df_missing[['Delivery_person_Ratings','humidity','weather_description_encoded','TARGET']])
df_missing
# Out:
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\3425202838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing['Distance (km)']=rf.predict(df_missing[['Delivery_person_Ratings','humidity','weather_description_encoded','TARGET']])
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37.0                      4.9            22.745049
# 2028                 24.0                      4.9            23.374989
# 2969                 28.0                      4.4            11.022477
# 9753                 30.0                      3.6            11.003669
# 9755                 37.0                      4.6            19.109300
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 0                75.892471                   22.765049
# 2028             85.335486                   23.424989
# 2969             76.995667                   11.112477
# 9753             76.976494                   11.083669
# 9755             72.825451                   19.199300
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                       75.912471        17.11      77.0            0.0
# 2028                    85.385486        17.84      68.0            0.0
# 2969                    77.085667        25.12      73.0            0.0
# 9753                    77.056494        25.97      73.0            0.0
# 9755                    72.915451        26.96      57.0            0.0
#
#       Distance (km)       TARGET  Type_of_vehicle_encoded  \
# 0            4.2880  21.66666667                        2
# 2028        16.1624  43.18333333                        2
# 2969        19.8820        45.85                        2
# 9753        14.2572  32.73333333                        2
# 9755        25.8712  70.33333333                        2
#
#       Type_of_order_encoded  weather_description_encoded  \
# 0                         3                            4
# 2028                      1                            1
# 2969                      1                            6
# 9753                      2                            4
# 9755                      2                           10
#
#       Traffic_Level_encoded
# 0                         1
# 2028                      0
# 2969                      0
# 9753                      0
# 9755                      3

# %%
df1.update(df_missing)
df1
# Out:
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\1780420071.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2 3 2 ... 2 3 3]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df1.update(df_missing)
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\1780420071.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[3 3 1 ... 2 0 2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df1.update(df_missing)
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\1780420071.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 4  6  6 ...  4  1 10]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df1.update(df_missing)
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\1780420071.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 3 1 ... 1 3 0]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df1.update(df_missing)
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37.0                      4.9            22.745049
# 1                    34.0                      4.5            12.913041
# 2                    23.0                      4.4            12.914264
# 3                    38.0                      4.7            11.003669
# 4                    32.0                      4.6            12.972793
# ...                   ...                      ...                  ...
# 9995                 25.0                      4.0            19.091458
# 9996                 32.0                      4.2            22.310237
# 9997                 36.0                      4.7            17.483216
# 9998                 37.0                      4.6            26.913987
# 9999                 29.0                      4.7            18.994237
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 0                75.892471                   22.765049
# 1                77.683237                   13.043041
# 2                77.678400                   12.924264
# 3                76.976494                   11.053669
# 4                80.249982                   13.012793
# ...                    ...                         ...
# 9995             72.827808                   19.101458
# 9996             73.158921                   22.400237
# 9997             78.552111                   17.493216
# 9998             75.752891                   27.053987
# 9999             72.825553                   19.084237
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                       75.912471        17.11      77.0            0.0
# 1                       77.813237        19.50      93.0            0.0
# 2                       77.688400        20.45      91.0            0.0
# 3                       77.026494        23.86      78.0            0.0
# 4                       80.289982        26.55      87.0            0.0
# ...                           ...          ...       ...            ...
# 9995                    72.837808        28.03      57.0            0.0
# 9996                    73.248921        23.96      64.0            0.0
# 9997                    78.562111        22.94      60.0            0.0
# 9998                    75.892891        23.72      31.0            0.0
# 9999                    72.915553        28.01      57.0            0.0
#
#       Distance (km)       TARGET  Type_of_vehicle_encoded  \
# 0             4.288  21.66666667                        2
# 1            37.170  85.26666667                        3
# 2             3.340  28.58333333                        2
# 3            10.050  35.18333333                        2
# 4             9.890        43.45                        3
# ...             ...          ...                      ...
# 9995          3.780         18.2                        2
# 9996         18.920  32.61666667                        2
# 9997          2.640  12.01666667                        2
# 9998         28.800  51.06666667                        3
# 9999         17.630         43.8                        3
#
#       Type_of_order_encoded  weather_description_encoded  \
# 0                         3                            4
# 1                         3                            6
# 2                         1                            6
# 3                         0                            6
# 4                         3                            6
# ...                     ...                          ...
# 9995                      2                           10
# 9996                      2                            4
# 9997                      2                            4
# 9998                      0                            1
# 9999                      2                           10
#
#       Traffic_Level_encoded
# 0                         1
# 1                         3
# 2                         1
# 3                         2
# 4                         0
# ...                     ...
# 9995                      1
# 9996                      0
# 9997                      1
# 9998                      3
# 9999                      0
#
# [9080 rows x 15 columns]

# %%
plot_correlations(df1, 'TARGET')

# %%
x=df1_clean[['Delivery_person_Ratings','temperature','weather_description_encoded','Distance (km)','Traffic_Level_encoded']]
y=df1_clean['TARGET'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rf.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print('The mean square error is :',mse)
print('The R2 score is :',r2)
# Out:
# The mean square error is : 27.314080893324764
# The R2 score is : 0.8990380402770886

# %%
column_to_check = "TARGET"  # You can change this to any column name

# Split into two datasets
df_no_missing = df1[df1[column_to_check].notna()]  # Rows where the column is NOT missing
df_missing = df1[df1[column_to_check].isna()]      # Rows where the column IS missing

df_missing.head()
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 7131                 21.0                      4.9            13.066762
# 7343                 30.0                      4.5             9.979186
# 7359                 35.0                      4.6            13.005801
# 7375                 35.0                      4.6             9.970717
# 7397                 35.0                      4.5            13.081878
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 7131             80.251865                   13.196762
# 7343             76.317361                    9.999186
# 7359             80.250744                   13.115801
# 7375             76.285447                   10.000717
# 7397             80.248519                   13.191878
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 7131                    80.381865        28.35      76.0           0.17
# 7343                    76.337361        25.68      83.0           0.45
# 7359                    80.360744        28.40      82.0           0.15
# 7375                    76.315447        25.94      81.0           0.40
# 7397                    80.358519        28.34      86.0           0.14
#
#       Distance (km) TARGET  Type_of_vehicle_encoded  Type_of_order_encoded  \
# 7131          28.92    NaN                        1                      3
# 7343           4.47    NaN                        1                      1
# 7359          26.06    NaN                        2                      1
# 7375           8.95    NaN                        1                      2
# 7397          25.34    NaN                        3                      2
#
#       weather_description_encoded  Traffic_Level_encoded
# 7131                            5                      3
# 7343                            5                      1
# 7359                            5                      3
# 7375                            5                      2
# 7397                            5                      3

# %%
df_missing['TARGET']=rf.predict(df_missing[['Delivery_person_Ratings','temperature','weather_description_encoded','Distance (km)','Traffic_Level_encoded']])
df_missing.head()
# Out:
# C:\Users\Cv\AppData\Local\Temp\ipykernel_11724\3096668363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing['TARGET']=rf.predict(df_missing[['Delivery_person_Ratings','temperature','weather_description_encoded','Distance (km)','Traffic_Level_encoded']])
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 7131                 21.0                      4.9            13.066762
# 7343                 30.0                      4.5             9.979186
# 7359                 35.0                      4.6            13.005801
# 7375                 35.0                      4.6             9.970717
# 7397                 35.0                      4.5            13.081878
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 7131             80.251865                   13.196762
# 7343             76.317361                    9.999186
# 7359             80.250744                   13.115801
# 7375             76.285447                   10.000717
# 7397             80.248519                   13.191878
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 7131                    80.381865        28.35      76.0           0.17
# 7343                    76.337361        25.68      83.0           0.45
# 7359                    80.360744        28.40      82.0           0.15
# 7375                    76.315447        25.94      81.0           0.40
# 7397                    80.358519        28.34      86.0           0.14
#
#       Distance (km)     TARGET  Type_of_vehicle_encoded  \
# 7131          28.92  65.154017                        1
# 7343           4.47  17.615222                        1
# 7359          26.06  59.595889                        2
# 7375           8.95  30.494833                        1
# 7397          25.34  62.505111                        3
#
#       Type_of_order_encoded  weather_description_encoded  \
# 7131                      3                            5
# 7343                      1                            5
# 7359                      1                            5
# 7375                      2                            5
# 7397                      2                            5
#
#       Traffic_Level_encoded
# 7131                      3
# 7343                      1
# 7359                      3
# 7375                      2
# 7397                      3

# %%
df1['precipitation'] = df1['precipitation'].astype(float)

df1.update(df_missing)
df1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 37.0                      4.9            22.745049
# 1                 34.0                      4.5            12.913041
# 2                 23.0                      4.4            12.914264
# 3                 38.0                      4.7            11.003669
# 4                 32.0                      4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                    75.912471        17.11      77.0            0.0
# 1                    77.813237        19.50      93.0            0.0
# 2                    77.688400        20.45      91.0            0.0
# 3                    77.026494        23.86      78.0            0.0
# 4                    80.289982        26.55      87.0            0.0
#
#    Distance (km)       TARGET  Type_of_vehicle_encoded  Type_of_order_encoded  \
# 0          4.288  21.66666667                        2                      3
# 1         37.170  85.26666667                        3                      3
# 2          3.340  28.58333333                        2                      1
# 3         10.050  35.18333333                        2                      0
# 4          9.890        43.45                        3                      3
#
#    weather_description_encoded  Traffic_Level_encoded
# 0                            4                      1
# 1                            6                      3
# 2                            6                      1
# 3                            6                      2
# 4                            6                      0

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# temperature                    0
# humidity                       0
# precipitation                  0
# Distance (km)                  0
# TARGET                         0
# Type_of_vehicle_encoded        0
# Type_of_order_encoded          0
# weather_description_encoded    0
# Traffic_Level_encoded          0
# dtype: int64

# %%
df1.shape
# Out:
# (9080, 15)

# %%
df2=df1
# Reversing the encoded columns
df2['Type_of_vehicle'] = le_veh.inverse_transform(df2['Type_of_vehicle_encoded'])
df2['Type_of_order'] = le_ord.inverse_transform(df2['Type_of_order_encoded'])
df2['weather_description'] = le_wea.inverse_transform(df2['weather_description_encoded'])
df2['Traffic_Level'] = le_tra.inverse_transform(df2['Traffic_Level_encoded'])
df2
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37.0                      4.9            22.745049
# 1                    34.0                      4.5            12.913041
# 2                    23.0                      4.4            12.914264
# 3                    38.0                      4.7            11.003669
# 4                    32.0                      4.6            12.972793
# ...                   ...                      ...                  ...
# 9995                 25.0                      4.0            19.091458
# 9996                 32.0                      4.2            22.310237
# 9997                 36.0                      4.7            17.483216
# 9998                 37.0                      4.6            26.913987
# 9999                 29.0                      4.7            18.994237
#
#       Restaurant_longitude  Delivery_location_latitude  \
# 0                75.892471                   22.765049
# 1                77.683237                   13.043041
# 2                77.678400                   12.924264
# 3                76.976494                   11.053669
# 4                80.249982                   13.012793
# ...                    ...                         ...
# 9995             72.827808                   19.101458
# 9996             73.158921                   22.400237
# 9997             78.552111                   17.493216
# 9998             75.752891                   27.053987
# 9999             72.825553                   19.084237
#
#       Delivery_location_longitude  temperature  humidity  precipitation  \
# 0                       75.912471        17.11      77.0            0.0
# 1                       77.813237        19.50      93.0            0.0
# 2                       77.688400        20.45      91.0            0.0
# 3                       77.026494        23.86      78.0            0.0
# 4                       80.289982        26.55      87.0            0.0
# ...                           ...          ...       ...            ...
# 9995                    72.837808        28.03      57.0            0.0
# 9996                    73.248921        23.96      64.0            0.0
# 9997                    78.562111        22.94      60.0            0.0
# 9998                    75.892891        23.72      31.0            0.0
# 9999                    72.915553        28.01      57.0            0.0
#
#       Distance (km)       TARGET  Type_of_vehicle_encoded  \
# 0             4.288  21.66666667                        2
# 1            37.170  85.26666667                        3
# 2             3.340  28.58333333                        2
# 3            10.050  35.18333333                        2
# 4             9.890        43.45                        3
# ...             ...          ...                      ...
# 9995          3.780         18.2                        2
# 9996         18.920  32.61666667                        2
# 9997          2.640  12.01666667                        2
# 9998         28.800  51.06666667                        3
# 9999         17.630         43.8                        3
#
#       Type_of_order_encoded  weather_description_encoded  \
# 0                         3                            4
# 1                         3                            6
# 2                         1                            6
# 3                         0                            6
# 4                         3                            6
# ...                     ...                          ...
# 9995                      2                           10
# 9996                      2                            4
# 9997                      2                            4
# 9998                      0                            1
# 9999                      2                           10
#
#       Traffic_Level_encoded Type_of_vehicle Type_of_order weather_description  \
# 0                         1     motorcycle         Snack                 haze
# 1                         3        scooter         Snack                 mist
# 2                         1     motorcycle        Drinks                 mist
# 3                         2     motorcycle        Buffet                 mist
# 4                         0        scooter         Snack                 mist
# ...                     ...             ...           ...                 ...
# 9995                      1     motorcycle          Meal                smoke
# 9996                      0     motorcycle          Meal                 haze
# 9997                      1     motorcycle          Meal                 haze
# 9998                      3        scooter        Buffet            clear sky
# 9999                      0        scooter          Meal                smoke
#
#      Traffic_Level
# 0              Low
# 1        Very High
# 2              Low
# 3         Moderate
# 4             High
# ...            ...
# 9995           Low
# 9996          High
# 9997           Low
# 9998     Very High
# 9999          High
#
# [9080 rows x 19 columns]

# %%
df2= df2.drop(columns=['Type_of_order_encoded','Type_of_vehicle_encoded','weather_description_encoded','Traffic_Level_encoded'],axis=1)

# %%
df.update(df2)
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  ...  humidity  \
# 0                    75.912471        Snack      motorcycle   ...      77.0
# 1                    77.813237        Snack         scooter   ...      93.0
# 2                    77.688400       Drinks      motorcycle   ...      91.0
# 3                    77.026494       Buffet      motorcycle   ...      78.0
# 4                    80.289982        Snack         scooter   ...      87.0
#
#    precipitation  weather_description Traffic_Level Distance (km)  \
# 0            0.0                 haze           Low         4.288
# 1            0.0                 mist     Very High        37.170
# 2            0.0                 mist           Low         3.340
# 3            0.0                 mist      Moderate        10.050
# 4            0.0                 mist          High         9.890
#
#         TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 0  21.66666667                       2                      3
# 1  85.26666667                       3                      3
# 2  28.58333333                       2                      1
# 3  35.18333333                       2                      0
# 4        43.45                       3                      3
#
#    weather_description_encoded  Traffic_Level_encoded
# 0                            4                      1
# 1                            6                      3
# 2                            6                      1
# 3                            6                      2
# 4                            6                      0
#
# [5 rows x 21 columns]

# %%
df.to_csv('clean_Food_Time_Data_set.csv', index=False)

# %%
for i in df1.columns:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[ (df[i] < lower_bound) | (df[i] > upper_bound) ]
    print(outliers.head())
    print(f'No of outliers in {i}',outliers.shape[0])
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 5362  430     BANGRES19DEL01                 50.0                      6.0
# 6394  427      JAPRES06DEL02                 50.0                      6.0
# 9499  3F0    BANGRES010DEL01                 50.0                      6.0
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 5362            12.914264             77.678400                   13.024264
# 6394            26.911927             75.797282                   27.041927
# 9499            12.933298             77.614293                   13.003298
#
#       Delivery_location_longitude Type_of_order    Type_of_vehicle  ...  \
# 5362                    77.788400         Meal   electric_scooter   ...
# 6394                    75.927282         Meal   electric_scooter   ...
# 9499                    77.684293       Drinks            scooter   ...
#
#       humidity  precipitation  weather_description Traffic_Level  \
# 5362      74.0            0.0                 haze     Very High
# 6394      29.0            0.0            clear sky     Very High
# 9499      73.0            0.0                 haze          High
#
#      Distance (km)       TARGET Type_of_vehicle_encoded  \
# 5362         27.03         55.8                       1
# 6394         28.81  59.68333333                       1
# 9499         14.22  46.86666667                       3
#
#       Type_of_order_encoded  weather_description_encoded  \
# 5362                      2                            4
# 6394                      2                            1
# 9499                      1                            4
#
#       Traffic_Level_encoded
# 5362                      3
# 6394                      3
# 9499                      0
#
# [3 rows x 21 columns]
# No of outliers in Delivery_person_Age 3
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 15   3AAB      MYSRES01DEL01                 35.0                      4.0
# 23   539B      MUMRES02DEL01                 25.0                      4.0
# 27   2288     BANGRES09DEL03                 32.0                      4.0
# 113  3F01      MUMRES15DEL01                 39.0                      3.8
# 148  4C88      MUMRES08DEL01                 31.0                      3.9
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 15             12.311072             76.654878                   12.351072
# 23             19.221315             72.862381                   19.261315
# 27             12.934179             77.615797                   13.024179
# 113            19.176269             72.836721                   19.286269
# 148            19.065838             72.832658                   19.135838
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  ...  humidity  \
# 15                     76.694878         Meal         scooter   ...      77.0
# 23                     72.902381       Buffet      motorcycle   ...      47.0
# 27                     77.705797       Buffet      motorcycle   ...      93.0
# 113                    72.946721       Drinks      motorcycle   ...      48.0
# 148                    72.902658       Buffet         scooter   ...      44.0
#
#      precipitation  weather_description Traffic_Level Distance (km)  \
# 15             0.0     scattered clouds      Moderate         10.51
# 23             0.0            clear sky          High          8.97
# 27             0.0                 mist     Very High         17.37
# 113            0.0            clear sky     Very High         25.68
# 148            0.0                smoke     Very High         17.15
#
#           TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 15         29.45                       3                      2
# 23   34.61666667                       2                      0
# 27   57.93333333                       2                      0
# 113  70.41666667                       2                      1
# 148  54.18333333                       3                      0
#
#      weather_description_encoded  Traffic_Level_encoded
# 15                             9                      2
# 23                             1                      0
# 27                             6                      3
# 113                            1                      3
# 148                           10                      3
#
# [5 rows x 21 columns]
# No of outliers in Delivery_person_Ratings 501
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Traffic_Level, Distance (km), TARGET, Type_of_vehicle_encoded, Type_of_order_encoded, weather_description_encoded, Traffic_Level_encoded]
# Index: []
#
# [0 rows x 21 columns]
# No of outliers in Restaurant_latitude 0
#       ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 6   95B4   RANCHIRES15DEL01                 33.0                      4.7
# 18  C9CF      KOLRES15DEL03                 21.0                      4.7
# 20  5795   RANCHIRES06DEL02                 31.0                      4.7
# 45  C644      KOLRES16DEL02                 37.0                      4.9
# 50  5554   RANCHIRES15DEL01                 31.0                      4.9
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 6             23.369746             85.339820                   23.479746
# 18            22.552672             88.352885                   22.582672
# 20            23.357804             85.325146                   23.487804
# 45            22.539129             88.365507                   22.559129
# 50            23.369746             85.339820                   23.409746
#
#     Delivery_location_longitude Type_of_order    Type_of_vehicle  ...  \
# 6                     85.449820         Meal            scooter   ...
# 18                    88.382885         Meal         motorcycle   ...
# 20                    85.455146         Meal   electric_scooter   ...
# 45                    88.385507        Snack            scooter   ...
# 50                    85.379820        Snack         motorcycle   ...
#
#     humidity  precipitation  weather_description Traffic_Level Distance (km)  \
# 6       69.0            0.0            clear sky          High         19.11
# 18      83.0            0.0                 haze      Moderate          8.07
# 20      67.0            0.0            clear sky     Very High         22.26
# 45      83.0            0.0                 haze           Low          5.32
# 50      68.0            0.0            clear sky      Moderate          8.81
#
#          TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 6   38.16666667                       3                      2
# 18  31.73333333                       2                      2
# 20  49.26666667                       1                      2
# 45  24.86666667                       3                      3
# 50  32.61666667                       2                      3
#
#     weather_description_encoded  Traffic_Level_encoded
# 6                             1                      0
# 18                            4                      2
# 20                            1                      3
# 45                            4                      1
# 50                            1                      2
#
# [5 rows x 21 columns]
# No of outliers in Restaurant_longitude 730
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Traffic_Level, Distance (km), TARGET, Type_of_vehicle_encoded, Type_of_order_encoded, weather_description_encoded, Traffic_Level_encoded]
# Index: []
#
# [0 rows x 21 columns]
# No of outliers in Delivery_location_latitude 0
#       ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 6   95B4   RANCHIRES15DEL01                 33.0                      4.7
# 18  C9CF      KOLRES15DEL03                 21.0                      4.7
# 20  5795   RANCHIRES06DEL02                 31.0                      4.7
# 45  C644      KOLRES16DEL02                 37.0                      4.9
# 50  5554   RANCHIRES15DEL01                 31.0                      4.9
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 6             23.369746             85.339820                   23.479746
# 18            22.552672             88.352885                   22.582672
# 20            23.357804             85.325146                   23.487804
# 45            22.539129             88.365507                   22.559129
# 50            23.369746             85.339820                   23.409746
#
#     Delivery_location_longitude Type_of_order    Type_of_vehicle  ...  \
# 6                     85.449820         Meal            scooter   ...
# 18                    88.382885         Meal         motorcycle   ...
# 20                    85.455146         Meal   electric_scooter   ...
# 45                    88.385507        Snack            scooter   ...
# 50                    85.379820        Snack         motorcycle   ...
#
#     humidity  precipitation  weather_description Traffic_Level Distance (km)  \
# 6       69.0            0.0            clear sky          High         19.11
# 18      83.0            0.0                 haze      Moderate          8.07
# 20      67.0            0.0            clear sky     Very High         22.26
# 45      83.0            0.0                 haze           Low          5.32
# 50      68.0            0.0            clear sky      Moderate          8.81
#
#          TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 6   38.16666667                       3                      2
# 18  31.73333333                       2                      2
# 20  49.26666667                       1                      2
# 45  24.86666667                       3                      3
# 50  32.61666667                       2                      3
#
#     weather_description_encoded  Traffic_Level_encoded
# 6                             1                      0
# 18                            4                      2
# 20                            1                      3
# 45                            4                      1
# 50                            1                      2
#
# [5 rows x 21 columns]
# No of outliers in Delivery_location_longitude 730
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 380  C595      DEHRES19DEL01                 29.0                      4.6
# 444  D800      DEHRES07DEL02                 37.0                      4.7
# 490  C1EC      DEHRES04DEL03                 32.0                      4.8
# 564  C951      DEHRES08DEL03                 36.0                      4.8
# 659  D398      DEHRES08DEL01                 22.0                      4.6
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 380            30.372202             78.077151                   30.442202
# 444            30.362686             78.068890                   30.492686
# 490            30.340722             78.060221                   30.430722
# 564            30.359722             78.067079                   30.499722
# 659            30.359722             78.067079                   30.469722
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  ...  humidity  \
# 380                    78.147151         Meal      motorcycle   ...      77.0
# 444                    78.198890       Buffet         scooter   ...      81.0
# 490                    78.150221       Buffet      motorcycle   ...      77.0
# 564                    78.207079       Buffet      motorcycle   ...      82.0
# 659                    78.177079        Snack      motorcycle   ...      80.0
#
#      precipitation  weather_description Traffic_Level Distance (km)  \
# 380            0.0            clear sky     Very High         23.51
# 444            0.0            clear sky     Very High         54.27
# 490            0.0            clear sky     Very High         27.89
# 564            0.0            clear sky     Very High         59.67
# 659            0.0            clear sky     Very High         32.95
#
#           TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 380  73.88333333                       2                      2
# 444  140.9833333                       3                      0
# 490        84.85                       2                      0
# 564       157.75                       2                      0
# 659  87.36666667                       2                      3
#
#      weather_description_encoded  Traffic_Level_encoded
# 380                            1                      3
# 444                            1                      3
# 490                            1                      3
# 564                            1                      3
# 659                            1                      3
#
# [5 rows x 21 columns]
# No of outliers in temperature 49
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Traffic_Level, Distance (km), TARGET, Type_of_vehicle_encoded, Type_of_order_encoded, weather_description_encoded, Traffic_Level_encoded]
# Index: []
#
# [0 rows x 21 columns]
# No of outliers in humidity 0
#             ID Delivery_person_ID  Delivery_person_Age  \
# 7131      764E    CHENRES010DEL02                 21.0
# 7343      D847      KOCRES20DEL02                 30.0
# 7359      10F0     CHENRES01DEL01                 35.0
# 7375      C5A2      KOCRES05DEL03                 35.0
# 7397  4.00E+23     CHENRES07DEL01                 35.0
#
#       Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 7131                      4.9            13.066762             80.251865
# 7343                      4.5             9.979186             76.317361
# 7359                      4.6            13.005801             80.250744
# 7375                      4.6             9.970717             76.285447
# 7397                      4.5            13.081878             80.248519
#
#       Delivery_location_latitude  Delivery_location_longitude Type_of_order  \
# 7131                   13.196762                    80.381865        Snack
# 7343                    9.999186                    76.337361       Drinks
# 7359                   13.115801                    80.360744       Drinks
# 7375                   10.000717                    76.315447         Meal
# 7397                   13.191878                    80.358519         Meal
#
#         Type_of_vehicle  ...  humidity  precipitation  weather_description  \
# 7131  electric_scooter   ...      76.0           0.17           light rain
# 7343  electric_scooter   ...      83.0           0.45           light rain
# 7359        motorcycle   ...      82.0           0.15           light rain
# 7375  electric_scooter   ...      81.0           0.40           light rain
# 7397           scooter   ...      86.0           0.14           light rain
#
#      Traffic_Level Distance (km)  TARGET Type_of_vehicle_encoded  \
# 7131     Very High         28.92     NaN                       1
# 7343           Low          4.47     NaN                       1
# 7359     Very High         26.06     NaN                       2
# 7375      Moderate          8.95     NaN                       1
# 7397     Very High         25.34     NaN                       3
#
#       Type_of_order_encoded  weather_description_encoded  \
# 7131                      3                            5
# 7343                      1                            5
# 7359                      1                            5
# 7375                      2                            5
# 7397                      2                            5
#
#       Traffic_Level_encoded
# 7131                      3
# 7343                      1
# 7359                      3
# 7375                      2
# 7397                      3
#
# [5 rows x 21 columns]
# No of outliers in precipitation 47
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 102  3C57      MUMRES14DEL02                 23.0                      4.8
# 444  D800      DEHRES07DEL02                 37.0                      4.7
# 454  548E      HYDRES04DEL02                 33.0                      4.8
# 564  C951      DEHRES08DEL03                 36.0                      4.8
# 614  CEF2    LUDHRES010DEL03                 38.0                      4.1
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 102            19.181300             72.836191                   19.311300
# 444            30.362686             78.068890                   30.492686
# 454            17.411028             78.329645                   17.541028
# 564            30.359722             78.067079                   30.499722
# 614            30.892860             75.822199                   31.032860
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  ...  humidity  \
# 102                    72.966191         Meal      motorcycle   ...      49.0
# 444                    78.198890       Buffet         scooter   ...      81.0
# 454                    78.459645         Meal      motorcycle   ...      67.0
# 564                    78.207079       Buffet      motorcycle   ...      82.0
# 614                    75.962199        Snack         scooter   ...      59.0
#
#      precipitation  weather_description Traffic_Level Distance (km)  \
# 102            0.0            clear sky     Very High         42.54
# 444            0.0            clear sky     Very High         54.27
# 454            0.0        broken clouds     Very High         53.49
# 564            0.0            clear sky     Very High         59.67
# 614            0.0            clear sky     Very High         43.62
#
#           TARGET Type_of_vehicle_encoded  Type_of_order_encoded  \
# 102  93.41666667                       2                      2
# 444  140.9833333                       3                      0
# 454  58.71666667                       2                      2
# 564       157.75                       2                      0
# 614  57.98333333                       3                      3
#
#      weather_description_encoded  Traffic_Level_encoded
# 102                            1                      3
# 444                            1                      3
# 454                            0                      3
# 564                            1                      3
# 614                            1                      3
#
# [5 rows x 21 columns]
# No of outliers in Distance (km) 72
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 for i in df1.columns:
# ----> 2     Q1 = df[i].quantile(0.25)
#       3     Q3 = df[i].quantile(0.75)
#       4     IQR = Q3 - Q1
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:2887, in Series.quantile(self, q, interpolation)
#    2883 # We dispatch to DataFrame so that core.internals only has to worry
#    2884 #  about 2D cases.
#    2885 df = self.to_frame()
# -> 2887 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888 if result.ndim == 2:
#    2889     result = result.iloc[:, 0]
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:12146, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12140 axis = self._get_axis_number(axis)
#   12142 if not is_list_like(q):
#   12143     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12144     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146     res_df = self.quantile(
#   12147         [q],  # type: ignore[list-item]
#   12148         axis=axis,
#   12149         numeric_only=numeric_only,
#   12150         interpolation=interpolation,
#   12151         method=method,
#   12152     )
#   12153     if method == "single":
#   12154         res = res_df.iloc[0]
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:12191, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12187     raise ValueError(
#   12188         f"Invalid method: {method}. Method must be in {valid_method}."
#   12189     )
#   12190 if method == "single":
# > 12191     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12192 elif method == "table":
#   12193     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1549, in BlockManager.quantile(self, qs, interpolation)
#    1545 new_axes = list(self.axes)
#    1546 new_axes[1] = Index(qs, dtype=np.float64)
#    1548 blocks = [
# -> 1549     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1550 ]
#    1552 return type(self)(blocks, new_axes)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1891, in Block.quantile(self, qs, interpolation)
#    1888 assert self.ndim == 2
#    1889 assert is_list_like(qs)  # caller is responsible for this
# -> 1891 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1892 # ensure_block_shape needed for cases where we start with EA and result
#    1893 #  is ndarray, e.g. IntegerArray, SparseArray
#    1894 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\quantile.py:199, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     195 if mask.any():
#     196     # Caller is responsible for ensuring mask shape match
#     197     assert mask.shape == values.shape
#     198     result = [
# --> 199         _nanpercentile_1d(val, m, qs, na_value, interpolation=interpolation)
#     200         for (val, m) in zip(list(values), list(mask))
#     201     ]
#     202     if values.dtype.kind == "f":
#     203         # preserve itemsize
#     204         result = np.asarray(result, dtype=values.dtype).T
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\quantile.py:145, in _nanpercentile_1d(values, mask, qs, na_value, interpolation)
#     139 if len(values) == 0:
#     140     # Can't pass dtype=values.dtype here bc we might have na_value=np.nan
#     141     #  with values.dtype=int64 see test_quantile_empty
#     142     # equiv: 'np.array([na_value] * len(qs))' but much faster
#     143     return np.full(len(qs), na_value)
# --> 145 return np.percentile(
#     146     values,
#     147     qs,
#     148     # error: No overload variant of "percentile" matches argument
#     149     # types "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]"
#     150     # , "Dict[str, str]"  [call-overload]
#     151     method=interpolation,  # type: ignore[call-overload]
#     152 )
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:4722, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4720     else:
#    4721         arr = a.copy()
# -> 4722 result = _quantile(arr,
#    4723                    quantiles=q,
#    4724                    axis=axis,
#    4725                    method=method,
#    4726                    out=out)
#    4727 return result
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:4841, in _quantile(arr, quantiles, axis, method, out)
#    4839     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4840     gamma = gamma.reshape(result_shape)
# -> 4841     result = _lerp(previous,
#    4842                    next,
#    4843                    gamma,
#    4844                    out=out)
#    4845 if np.any(slices_having_nans):
#    4846     if result.ndim == 0 and out is None:
#    4847         # can't write to a scalar, but indexing will be correct
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:4655, in _lerp(a, b, t, out)
#    4641 def _lerp(a, b, t, out=None):
#    4642     """
#    4643     Compute the linear interpolation weighted by gamma on each point of
#    4644     two same shape array.
#    (...)
#    4653         Output array.
#    4654     """
# -> 4655     diff_b_a = subtract(b, a)
#    4656     # asanyarray is a stop-gap until gh-13105
#    4657     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
for i in df1.columns:
    print(f'skewness of column ({i}) :',skew(df1[i]))
# Out:
# skewness of column (Delivery_person_Age) : 0.0018565858949964008
# skewness of column (Delivery_person_Ratings) : -2.257495464296344
# skewness of column (Restaurant_latitude) : 0.10863766009077902
# skewness of column (Restaurant_longitude) : 1.2074722087286747
# skewness of column (Delivery_location_latitude) : 0.10950998400501263
# skewness of column (Delivery_location_longitude) : 1.2065472515304456
# skewness of column (temperature) : -0.2808316684124877
# skewness of column (humidity) : -0.09024027325017575
# skewness of column (precipitation) : 24.43420423082586
# skewness of column (Distance (km)) : 0.7402533031242352
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 for i in df1.columns:
# ----> 2     print(f'skewness of column ({i}) :',skew(df1[i]))
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:573, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     570     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     571     return tuple_to_result(*res)
# --> 573 res = hypotest_fun_out(*samples, **kwds)
#     574 res = result_to_tuple(res)
#     575 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:1200, in skew(a, axis, bias, nan_policy)
#    1197 a, axis = _chk_asarray(a, axis, xp=xp)
#    1198 n = a.shape[axis]
# -> 1200 mean = xp.mean(a, axis=axis, keepdims=True)
#    1201 mean_reduced = xp.squeeze(mean, axis=axis)  # needed later
#    1202 m2 = _moment(a, 2, axis, mean=mean, xp=xp)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# TypeError: can only concatenate str (not "float") to str

# %%
def plot_regression_analysis(df, x_col):
    """
    Perform and plot both linear and quadratic regression for each column against x_col.
    
    Parameters:
    df (pd.DataFrame): Input DataFrame
    x_col (str): Name of the column to use as independent variable (x-axis)
    """
    # Ensure x_col exists in DataFrame
    if x_col not in df.columns:
        print(f"Error: Column '{x_col}' not found in DataFrame")
        return
    
    # Prepare x data
    X = df[x_col].values.reshape(-1, 1)
    
    for y_col in df.columns:
        if y_col == x_col:
            continue  # Skip comparing the same column
        
        y = df[y_col].values
        
        # Linear regression
        linear_model = LinearRegression()
        linear_model.fit(X, y)
        y_pred_linear = linear_model.predict(X)
        r2_linear = r2_score(y, y_pred_linear)
        
        # Quadratic regression (y = ax² + bx + c)
        poly = PolynomialFeatures(degree=2)
        X_poly = poly.fit_transform(X)
        quad_model = LinearRegression()
        quad_model.fit(X_poly, y)
        y_pred_quad = quad_model.predict(X_poly)
        r2_quad = r2_score(y, y_pred_quad)
        
        # Create plot
        plt.figure(figsize=(10, 6))
        
        # Scatter plot of actual data
        plt.scatter(X, y, color='blue', label='Actual Data', alpha=0.5)
        
        # Sort values for smooth regression lines
        X_sorted = np.sort(X, axis=0)
        X_sorted_poly = poly.transform(X_sorted)
        
        # Plot linear regression
        plt.plot(X_sorted, linear_model.predict(X_sorted), 
                color='red', label=f'Linear (R²={r2_linear:.3f})')
        
        # Plot quadratic regression
        plt.plot(X_sorted, quad_model.predict(X_sorted_poly), 
                color='green', label=f'Quadratic (R²={r2_quad:.3f})')
        
        plt.xlabel(x_col)
        plt.ylabel(y_col)
        plt.title(f'Regression Analysis: {y_col} vs {x_col}\n'
                 f'Linear (red) vs Quadratic (green)')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()
        
        # Print model coefficients
        print(f"\nRegression results for {y_col} ~ {x_col}:")
        print(f"Linear model: y = {linear_model.coef_[0]:.4f}x + {linear_model.intercept_:.4f}")
        print(f"Quadratic model: y = {quad_model.coef_[2]:.4f}x² + {quad_model.coef_[1]:.4f}x + {quad_model.coef_[0]:.4f}")
        print(f"R² improvement from linear to quadratic: {r2_quad - r2_linear:.4f}\n")

plot_regression_analysis(df1, 'Distance (km)')

# %%
for i in df1.columns:
    plt.scatter(df1['Distance (km)'],df1[i])
    plt.xlabel('Distance (km)')
    plt.ylabel(i)
    plt.title('Regression')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 for i in df1.columns:
# ----> 2     plt.scatter(df1['Distance (km)'],df1[i])
#       3     plt.xlabel('Distance (km)')
#       4     plt.ylabel(i)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
#    1493                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:4781, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4779 edgecolors = kwargs.pop('edgecolor', None)
#    4780 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4781 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4782 # np.ma.ravel yields an ndarray, not a masked array,
#    4783 # unless its argument is a masked array.
#    4784 x = np.ma.ravel(x)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:2585, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2583     # Update from data if axis is already set but no unit is set yet.
#    2584     if axis is not None and data is not None and not axis.have_units():
# -> 2585         axis.update_units(data)
#    2586 for axis_name, axis in axis_map.items():
#    2587     # Return if no axis is set.
#    2588     if axis is None:
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1747, in Axis.update_units(self, data)
#    1745 neednew = self.converter != converter
#    1746 self.converter = converter
# -> 1747 default = self.converter.default_units(data, self)
#    1748 if default is not None and self.units is None:
#    1749     self.set_units(default)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
#      89     names.remove("None")
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
columns_to_check = ['TARGET', 'Distance (km)']

# Find rows where only one column is missing (not both)
rows_with_single_missing = []

for idx, row in df[columns_to_check].iterrows():
    missing_count = row.isna().sum()
    if missing_count == 1:  # Only one missing (not both)
        rows_with_single_missing.append(idx)

print("Rows where only one value is missing (not both):", rows_with_single_missing)
# Out:
# Rows where only one value is missing (not both): [0, 2028, 2969, 7131, 7343, 7359, 7375, 7397, 7398, 7430, 7451, 7455, 7496, 7572, 7576, 7586, 7607, 7613, 7628, 7637, 7647, 7663, 7697, 7763, 7767, 7780, 7791, 7798, 7813, 7817, 7824, 7875, 7903, 7904, 7932, 7934, 7938, 7969, 7973, 7993, 9753, 9755, 9789, 9802, 9964]

# %%
numerical_cols = ["Distance (km)", "temperature", "humidity"]

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    plt.scatter(df['Traffic_Level'], df[col], alpha=0.7)
    plt.xlabel('Traffic Level')
    plt.ylabel(col)
    plt.title(f'{col} vs Traffic Level')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# --- 2. Heatmap of correlations between numeric variables ---
plt.figure(figsize=(8, 6))
corr = df[numerical_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation between numeric variables")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       3 for col in numerical_cols:
#       4     plt.figure(figsize=(6, 4))
# ----> 5     plt.scatter(df['Traffic_Level'], df[col], alpha=0.7)
#       6     plt.xlabel('Traffic Level')
#       7     plt.ylabel(col)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
#    1493                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:4781, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4779 edgecolors = kwargs.pop('edgecolor', None)
#    4780 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4781 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4782 # np.ma.ravel yields an ndarray, not a masked array,
#    4783 # unless its argument is a masked array.
#    4784 x = np.ma.ravel(x)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:2585, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2583     # Update from data if axis is already set but no unit is set yet.
#    2584     if axis is not None and data is not None and not axis.have_units():
# -> 2585         axis.update_units(data)
#    2586 for axis_name, axis in axis_map.items():
#    2587     # Return if no axis is set.
#    2588     if axis is None:
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1747, in Axis.update_units(self, data)
#    1745 neednew = self.converter != converter
#    1746 self.converter = converter
# -> 1747 default = self.converter.default_units(data, self)
#    1748 if default is not None and self.units is None:
#    1749     self.set_units(default)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File c:\Users\Cv\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
#      89     names.remove("None")
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
